# %% [markdown]
# # Lambda/Anonymous Functions
#
# In Python, anonymous function is a function that is defined without a name.
#
# While normal functions are defined using the def keyword, in Python anonymous functions are defined using the lambda keyword.
#
# Lambda functions are used extensively along with built in functions like filter(), map(), reduce()
#
# > Syntax: `lambda arguments: expression`

# %% [markdown]
# ## Examples:

# %%
def double(x):
  return x*2

print(double(5))
# Out:
# 10

# %% [markdown]
# same thing can be done using lambda in the following way

# %%
double = lambda x: x*2

print(double(5))
# Out:
# 10

# %% [markdown]
# Now lets look at using lambda in filter,map and reduce.

# %%
#Example use with filter()
lst = [2,6,3,8,4,1,56,7,5,29]
even_lst = list(filter(lambda x: x%2 == 0, lst))
print(even_lst)
# Out:
# [2, 6, 8, 4, 56]

# %%
#Example use with map()
square_lst = list(map(lambda x: x*x, lst))
print(square_lst)
# Out:
# [4, 36, 9, 64, 16, 1, 3136, 49, 25, 841]

# %%
#Example use with reduce()
from functools import reduce

lst_product = reduce(lambda x, y: x*y,lst)
print(lst_product)
# Out:
# 65479680
