# %% [markdown]
# # Problem
#
# Given two list our task isto find the elements which are common in both the list and print them

# %% [markdown]
# ### Simple algorithm

# %%
def printCommonElements(lst1, lst2):
    for i in lst1:
        for j in lst2:
            if i==j:
                print(i)
                break

# %% [markdown]
# Ignoring duplicates and other boundary cases for simplicity

# %%
lst1 = [1,5,9,6,3]
lst2 = [6,0,3,8,2]

printCommonElements(lst1, lst2)
# Out:
# 6
# 3

# %% [markdown]
# > Time complexity: O(m*n)
#
# where m:length of lst1 and n:length of lst 2
#
# > Space complexity: O(1)

# %% [markdown]
# we will see the improved version of above code in the next lecture [here](https://colab.research.google.com/drive/1TowQYn0fbkFZhne20TOA_2X21CoenGtq?usp=sharing)
